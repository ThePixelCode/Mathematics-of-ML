# %% [markdown]
# <a href="https://colab.research.google.com/github/ThePixelCode/Mathematics-of-ML/blob/notebook-8-3/8_3_Double_Descent.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Notebook 8.3: Double Descent**
#
# This notebook investigates double descent as described in section 8.4 of the book.
#
# It uses the MNIST-1D database which can be found at https://github.com/greydanus/mnist1d
#
# Work through the cells below, running each cell in turn. In various places you will see the words "TO DO". Follow the instructions at these places and make predictions about what is going to happen or write code to complete the functions.
#
# Contact me at udlbookmail@gmail.com if you find any mistakes or have any suggestions.

# %%
# Run this if you're in a Colab to install MNIST 1D repository
# !pip install git+https://github.com/greydanus/mnist1d
# Out:
# Collecting git+https://github.com/greydanus/mnist1d
#   Cloning https://github.com/greydanus/mnist1d to /tmp/pip-req-build-8fk08ta2
#   Running command git clone --filter=blob:none --quiet https://github.com/greydanus/mnist1d /tmp/pip-req-build-8fk08ta2
#   Resolved https://github.com/greydanus/mnist1d to commit 350929d12f4c9a4b7355e0c96604e41b9239bdb4
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from mnist1d==0.0.2.post9) (2.31.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from mnist1d==0.0.2.post9) (1.25.2)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.10/dist-packages (from mnist1d==0.0.2.post9) (3.7.1)
# Requirement already satisfied: scipy in /usr/local/lib/python3.10/dist-packages (from mnist1d==0.0.2.post9) (1.11.4)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->mnist1d==0.0.2.post9) (1.2.1)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib->mnist1d==0.0.2.post9) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->mnist1d==0.0.2.post9) (4.53.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->mnist1d==0.0.2.post9) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->mnist1d==0.0.2.post9) (24.1)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->mnist1d==0.0.2.post9) (9.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->mnist1d==0.0.2.post9) (3.1.2)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib->mnist1d==0.0.2.post9) (2.8.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->mnist1d==0.0.2.post9) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->mnist1d==0.0.2.post9) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->mnist1d==0.0.2.post9) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->mnist1d==0.0.2.post9) (2024.7.4)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.7->matplotlib->mnist1d==0.0.2.post9) (1.16.0)
# Building wheels for collected packages: mnist1d
#   Building wheel for mnist1d (pyproject.toml) ... done
#   Created wheel for mnist1d: filename=mnist1d-0.0.2.post9-py3-none-any.whl size=14496 sha256=824d0ac6e426407c965debda817a1e47a95a9925a16229a21cf971618b06c0a7
#   Stored in directory: /tmp/pip-ephem-wheel-cache-kcw3eobs/wheels/41/95/55/45fcf7d38cfa97e35682da6c5017d4513729131326ce935371
# Successfully built mnist1d
# Installing collected packages: mnist1d
# Successfully installed mnist1d-0.0.2.post9

# %%
import torch, torch.nn as nn
from torch.utils.data import TensorDataset, DataLoader
from torch.optim.lr_scheduler import StepLR
import numpy as np
import matplotlib.pyplot as plt
import mnist1d
import random
random.seed(0)

# Try attaching to GPU -- Use "Change Runtime Type to change to GPUT"
DEVICE = str(torch.device('cuda' if torch.cuda.is_available() else 'cpu'))
print('Using:', DEVICE)
# Out:
# Using: cuda

# %%
args = mnist1d.data.get_dataset_args()
args.num_samples = 8000
args.train_split = 0.5
args.corr_noise_scale = 0.25
args.iid_noise_scale=2e-2
data = mnist1d.data.get_dataset(args, path='./mnist1d_data.pkl', download=False, regenerate=True)

# Add 15% noise to training labels
for c_y in range(len(data['y'])):
    random_number = random.random()
    if random_number < 0.15 :
        random_int = int(random.random() * 10)
        data['y'][c_y] = random_int

# The training and test input and outputs are in
# data['x'], data['y'], data['x_test'], and data['y_test']
print("Examples in training set: {}".format(len(data['y'])))
print("Examples in test set: {}".format(len(data['y_test'])))
print("Dimensionality of each example: {}".format(data['x'].shape[-1]))
# Out:
# Did or could not load data from ./mnist1d_data.pkl. Rebuilding dataset...
# Examples in training set: 4000
# Examples in test set: 4000
# Dimensionality of each example: 40

# %%
# Initialize the parameters with He initialization
def weights_init(layer_in):
  if isinstance(layer_in, nn.Linear):
    nn.init.kaiming_uniform_(layer_in.weight)
    layer_in.bias.data.fill_(0.0)

# Return an initialized model with two hidden layers and n_hidden hidden units at each
def get_model(n_hidden):

  D_i = 40    # Input dimensions
  D_k = n_hidden   # Hidden dimensions
  D_o = 10    # Output dimensions

  # Define a model with two hidden layers
  # And ReLU activations between them
  model = nn.Sequential(
  nn.Linear(D_i, D_k),
  nn.ReLU(),
  nn.Linear(D_k, D_k),
  nn.ReLU(),
  nn.Linear(D_k, D_o))

  # Call the function you just defined
  model.apply(weights_init)

  # Return the model
  return model ;

# %%
def fit_model(model, data, n_epoch):

  # choose cross entropy loss function (equation 5.24)
  loss_function = torch.nn.CrossEntropyLoss()
  # construct SGD optimizer and initialize learning rate and momentum
  # optimizer = torch.optim.Adam(model.parameters(), lr=0.01)
  optimizer = torch.optim.SGD(model.parameters(), lr = 0.01, momentum=0.9)


  x_train = torch.tensor(data['x'].astype('float32'))
  y_train = torch.tensor(data['y'].transpose().astype('long'))
  x_test= torch.tensor(data['x_test'].astype('float32'))
  y_test = torch.tensor(data['y_test'].astype('long'))

  # load the data into a class that creates the batches
  data_loader = DataLoader(TensorDataset(x_train,y_train), batch_size=100, shuffle=True, worker_init_fn=np.random.seed(1))

  for epoch in range(n_epoch):
    # loop over batches
    for i, batch in enumerate(data_loader):
      # retrieve inputs and labels for this batch
      x_batch, y_batch = batch
      # zero the parameter gradients
      optimizer.zero_grad()
      # forward pass -- calculate model output
      pred = model(x_batch)
      # compute the loss
      loss = loss_function(pred, y_batch)
      # backward pass
      loss.backward()
      # SGD update
      optimizer.step()

    # Run whole dataset to get statistics -- normally wouldn't do this
    pred_train = model(x_train)
    pred_test = model(x_test)
    _, predicted_train_class = torch.max(pred_train.data, 1)
    _, predicted_test_class = torch.max(pred_test.data, 1)
    errors_train = 100 - 100 * (predicted_train_class == y_train).float().sum() / len(y_train)
    errors_test= 100 - 100 * (predicted_test_class == y_test).float().sum() / len(y_test)
    losses_train = loss_function(pred_train, y_train).item()
    losses_test= loss_function(pred_test, y_test).item()
    if epoch%100 ==0 :
      print(f'Epoch {epoch:5d}, train loss {losses_train:.6f}, train error {errors_train:3.2f},  test loss {losses_test:.6f}, test error {errors_test:3.2f}')

  return errors_train, errors_test

# %%
def count_parameters(model):
    return sum(p.numel() for p in model.parameters() if p.requires_grad)

# %% [markdown]
# The following code produces the double descent curve by training the model with different numbers of hidden units and plotting the test error.
#
# TO DO:
#
# *Before* you run the code, and considering that there are 4000 training examples predict:<br>
#
# 1.    At what capacity do you think the training error will become zero?
# 2.   At what capacity do you expect the first minima of the double descent curve to appear?
# 3. At what capacity do you expect the maximum of the double descent curve to appear?

# %% [markdown]
# 1.   After the 300 hidden variables
# 2.   In the beginning of the iterations
# 3.   In the middle until the end

# %%
# This code will take a while (~30 mins on GPU) to run!  Go and make a cup of coffee!

hidden_variables = np.array([2,4,6,8,10,14,18,22,26,30,35,40,45,50,55,60,70,80,90,100,120,140,160,180,200,250,300,400]) ;

errors_train_all = np.zeros_like(hidden_variables)
errors_test_all = np.zeros_like(hidden_variables)
total_weights_all = np.zeros_like(hidden_variables)

# loop over the dataset n_epoch times
n_epoch = 1000

# For each hidden variable size
for c_hidden in range(len(hidden_variables)):
    print(f'Training model with {hidden_variables[c_hidden]:3d} hidden variables')
    # Get a model
    model = get_model(hidden_variables[c_hidden]) ;
    # Count and store number of weights
    total_weights_all[c_hidden] = count_parameters(model)
    # Train the model
    errors_train, errors_test = fit_model(model, data, n_epoch)
    # Store the results
    errors_train_all[c_hidden] = errors_train
    errors_test_all[c_hidden]= errors_test
# Out:
# Training model with   2 hidden variables
# Epoch     0, train loss 2.287646, train error 88.22,  test loss 2.283024, test error 88.57
# Epoch   100, train loss 1.918208, train error 71.75,  test loss 1.765122, test error 68.85
# Epoch   200, train loss 1.906057, train error 70.95,  test loss 1.735423, test error 68.95
# Epoch   300, train loss 1.904501, train error 71.47,  test loss 1.722719, test error 69.55
# Epoch   400, train loss 1.902432, train error 71.62,  test loss 1.724484, test error 69.45
# Epoch   500, train loss 1.901095, train error 70.60,  test loss 1.724817, test error 68.38
# Epoch   600, train loss 1.900893, train error 70.78,  test loss 1.728321, test error 67.93
# Epoch   700, train loss 1.901007, train error 71.88,  test loss 1.732705, test error 69.88
# Epoch   800, train loss 1.904563, train error 70.80,  test loss 1.741016, test error 68.72
# Epoch   900, train loss 1.901891, train error 71.03,  test loss 1.735383, test error 68.97
# Training model with   4 hidden variables
# Epoch     0, train loss 2.217721, train error 86.40,  test loss 2.192198, test error 85.53
# Epoch   100, train loss 1.751748, train error 63.72,  test loss 1.600551, test error 61.05
# Epoch   200, train loss 1.735955, train error 63.53,  test loss 1.592859, test error 61.25
# Epoch   300, train loss 1.733965, train error 63.92,  test loss 1.593289, test error 61.78
# Epoch   400, train loss 1.725955, train error 63.75,  test loss 1.592581, test error 61.55
# Epoch   500, train loss 1.724765, train error 63.92,  test loss 1.580769, test error 61.15
# Epoch   600, train loss 1.728979, train error 63.62,  test loss 1.585374, test error 61.17
# Epoch   700, train loss 1.724068, train error 63.53,  test loss 1.587681, test error 61.00
# Epoch   800, train loss 1.722278, train error 62.88,  test loss 1.592404, test error 61.38
# Epoch   900, train loss 1.724080, train error 63.08,  test loss 1.598149, test error 61.25
# Training model with   6 hidden variables
# Epoch     0, train loss 2.160837, train error 82.07,  test loss 2.115347, test error 79.47
# Epoch   100, train loss 1.649097, train error 58.42,  test loss 1.474980, test error 56.08
# Epoch   200, train loss 1.596249, train error 55.90,  test loss 1.406945, test error 53.20
# Epoch   300, train loss 1.568463, train error 54.58,  test loss 1.405498, test error 52.42
# Epoch   400, train loss 1.565428, train error 54.58,  test loss 1.397285, test error 52.67
# Epoch   500, train loss 1.559197, train error 54.20,  test loss 1.391534, test error 52.40
# Epoch   600, train loss 1.557152, train error 54.62,  test loss 1.405880, test error 52.67
# Epoch   700, train loss 1.552495, train error 53.92,  test loss 1.391457, test error 52.20
# Epoch   800, train loss 1.552110, train error 53.90,  test loss 1.401791, test error 52.20
# Epoch   900, train loss 1.551230, train error 54.25,  test loss 1.410725, test error 52.30
# Training model with   8 hidden variables
# Epoch     0, train loss 2.273789, train error 85.03,  test loss 2.267343, test error 84.50
# Epoch   100, train loss 1.595064, train error 55.85,  test loss 1.442901, test error 54.83
# Epoch   200, train loss 1.565649, train error 54.42,  test loss 1.437234, test error 53.97
# Epoch   300, train loss 1.550613, train error 54.53,  test loss 1.447466, test error 54.40
# Epoch   400, train loss 1.540426, train error 54.00,  test loss 1.456062, test error 54.92
# Epoch   500, train loss 1.531563, train error 53.78,  test loss 1.468316, test error 55.92
# Epoch   600, train loss 1.530236, train error 53.90,  test loss 1.476518, test error 55.78
# Epoch   700, train loss 1.526964, train error 53.45,  test loss 1.482508, test error 56.75
# Epoch   800, train loss 1.517499, train error 52.88,  test loss 1.485103, test error 56.03
# Epoch   900, train loss 1.522027, train error 53.25,  test loss 1.488400, test error 56.10
# Training model with  10 hidden variables
# Epoch     0, train loss 2.238495, train error 84.68,  test loss 2.231003, test error 85.72
# Epoch   100, train loss 1.578729, train error 55.03,  test loss 1.427413, test error 54.58
# Epoch   200, train loss 1.490439, train error 51.15,  test loss 1.393596, test error 53.35
# Epoch   300, train loss 1.477956, train error 50.42,  test loss 1.403261, test error 52.60
# Epoch   400, train loss 1.468902, train error 50.00,  test loss 1.410278, test error 52.30
# Epoch   500, train loss 1.462262, train error 49.30,  test loss 1.417149, test error 53.30
# Epoch   600, train loss 1.458027, train error 49.70,  test loss 1.430811, test error 53.65
# Epoch   700, train loss 1.448891, train error 50.33,  test loss 1.416067, test error 53.20
# Epoch   800, train loss 1.445780, train error 50.70,  test loss 1.422120, test error 53.05
# Epoch   900, train loss 1.437735, train error 49.92,  test loss 1.429703, test error 52.47
# Training model with  14 hidden variables
# Epoch     0, train loss 2.246206, train error 84.00,  test loss 2.227340, test error 83.55
# Epoch   100, train loss 1.424866, train error 48.12,  test loss 1.303708, test error 48.53
# Epoch   200, train loss 1.344522, train error 45.08,  test loss 1.296411, test error 47.83
# Epoch   300, train loss 1.310509, train error 44.10,  test loss 1.327338, test error 49.05
# Epoch   400, train loss 1.282549, train error 43.65,  test loss 1.329070, test error 48.40
# Epoch   500, train loss 1.271455, train error 43.12,  test loss 1.347555, test error 49.55
# Epoch   600, train loss 1.267302, train error 42.70,  test loss 1.353822, test error 49.08
# Epoch   700, train loss 1.255297, train error 42.38,  test loss 1.367211, test error 49.22
# Epoch   800, train loss 1.256437, train error 42.38,  test loss 1.376367, test error 49.90
# Epoch   900, train loss 1.250408, train error 42.40,  test loss 1.380721, test error 49.90
# Training model with  18 hidden variables
# Epoch     0, train loss 2.252318, train error 82.85,  test loss 2.229082, test error 82.50
# Epoch   100, train loss 1.333256, train error 44.53,  test loss 1.294353, test error 48.12
# Epoch   200, train loss 1.240114, train error 41.33,  test loss 1.307791, test error 47.95
# Epoch   300, train loss 1.188587, train error 40.58,  test loss 1.340500, test error 49.15
# Epoch   400, train loss 1.161960, train error 39.67,  test loss 1.387152, test error 49.20
# Epoch   500, train loss 1.140430, train error 38.78,  test loss 1.400422, test error 48.80
# Epoch   600, train loss 1.130928, train error 38.58,  test loss 1.416320, test error 49.58
# Epoch   700, train loss 1.115472, train error 36.95,  test loss 1.440821, test error 50.12
# Epoch   800, train loss 1.121786, train error 37.50,  test loss 1.483389, test error 51.08
# Epoch   900, train loss 1.104668, train error 37.22,  test loss 1.482132, test error 50.15
# Training model with  22 hidden variables
# Epoch     0, train loss 2.266832, train error 85.18,  test loss 2.283296, test error 85.82
# Epoch   100, train loss 1.258424, train error 40.88,  test loss 1.251967, test error 46.62
# Epoch   200, train loss 1.148138, train error 37.60,  test loss 1.309436, test error 46.00
# Epoch   300, train loss 1.082930, train error 35.72,  test loss 1.366130, test error 47.53
# Epoch   400, train loss 1.044942, train error 34.40,  test loss 1.429364, test error 48.17
# Epoch   500, train loss 1.018774, train error 33.62,  test loss 1.500084, test error 49.22
# Epoch   600, train loss 1.005111, train error 33.45,  test loss 1.562731, test error 49.35
# Epoch   700, train loss 0.985733, train error 31.88,  test loss 1.606051, test error 49.85
# Epoch   800, train loss 0.975970, train error 31.95,  test loss 1.646446, test error 50.30
# Epoch   900, train loss 0.966715, train error 32.22,  test loss 1.690300, test error 50.55
# Training model with  26 hidden variables
# Epoch     0, train loss 2.175563, train error 80.25,  test loss 2.137960, test error 80.05
# Epoch   100, train loss 1.203501, train error 39.70,  test loss 1.359970, test error 50.50
# Epoch   200, train loss 1.061290, train error 35.65,  test loss 1.496557, test error 52.45
# Epoch   300, train loss 0.982236, train error 32.57,  test loss 1.591426, test error 52.50
# Epoch   400, train loss 0.928826, train error 31.15,  test loss 1.734877, test error 53.78
# Epoch   500, train loss 0.900101, train error 30.57,  test loss 1.837306, test error 54.40
# Epoch   600, train loss 0.865122, train error 29.90,  test loss 1.925461, test error 54.15
# Epoch   700, train loss 0.845352, train error 29.25,  test loss 1.985887, test error 54.40
# Epoch   800, train loss 0.831674, train error 29.20,  test loss 2.071426, test error 54.08
# Epoch   900, train loss 0.836588, train error 29.38,  test loss 2.146222, test error 54.55
# Training model with  30 hidden variables
# Epoch     0, train loss 2.248241, train error 83.22,  test loss 2.231086, test error 82.93
# Epoch   100, train loss 1.102710, train error 35.93,  test loss 1.365851, test error 49.42
# Epoch   200, train loss 0.910765, train error 30.30,  test loss 1.534627, test error 50.00
# Epoch   300, train loss 0.833289, train error 27.65,  test loss 1.779400, test error 53.17
# Epoch   400, train loss 0.779860, train error 26.03,  test loss 1.963184, test error 53.75
# Epoch   500, train loss 0.741436, train error 25.47,  test loss 2.079391, test error 53.50
# Epoch   600, train loss 0.722997, train error 25.00,  test loss 2.202067, test error 53.78
# Epoch   700, train loss 0.684424, train error 23.38,  test loss 2.338996, test error 54.70
# Epoch   800, train loss 0.686917, train error 23.60,  test loss 2.477038, test error 53.80
# Epoch   900, train loss 0.670822, train error 22.82,  test loss 2.570140, test error 54.60
# Training model with  35 hidden variables
# Epoch     0, train loss 2.167433, train error 80.88,  test loss 2.123792, test error 78.65
# Epoch   100, train loss 1.005734, train error 33.32,  test loss 1.404424, test error 49.47
# Epoch   200, train loss 0.777119, train error 26.18,  test loss 1.725926, test error 52.30
# Epoch   300, train loss 0.671789, train error 22.72,  test loss 2.133304, test error 54.62
# Epoch   400, train loss 0.599456, train error 19.68,  test loss 2.439060, test error 55.15
# Epoch   500, train loss 0.565223, train error 18.82,  test loss 2.787168, test error 55.00
# Epoch   600, train loss 0.525023, train error 17.75,  test loss 3.093895, test error 56.75
# Epoch   700, train loss 0.491932, train error 15.72,  test loss 3.413535, test error 56.92
# Epoch   800, train loss 0.521655, train error 17.38,  test loss 3.710908, test error 58.30
# Epoch   900, train loss 0.476908, train error 16.07,  test loss 3.920845, test error 57.38
# Training model with  40 hidden variables
# Epoch     0, train loss 2.060936, train error 76.68,  test loss 2.016643, test error 77.18
# Epoch   100, train loss 0.929606, train error 29.72,  test loss 1.523316, test error 52.65
# Epoch   200, train loss 0.626840, train error 20.18,  test loss 2.019492, test error 54.42
# Epoch   300, train loss 0.507180, train error 16.85,  test loss 2.613700, test error 54.65
# Epoch   400, train loss 0.397478, train error 12.93,  test loss 3.210179, test error 56.08
# Epoch   500, train loss 0.334815, train error 11.18,  test loss 3.857324, test error 56.62
# Epoch   600, train loss 0.274930, train error 8.68,  test loss 4.664356, test error 57.83
# Epoch   700, train loss 0.285337, train error 10.35,  test loss 5.455247, test error 58.40
# Epoch   800, train loss 0.319893, train error 11.57,  test loss 6.222248, test error 58.22
# Epoch   900, train loss 0.253139, train error 9.45,  test loss 6.592029, test error 58.08
# Training model with  45 hidden variables
# Epoch     0, train loss 2.089176, train error 77.60,  test loss 2.068769, test error 77.85
# Epoch   100, train loss 0.831210, train error 26.90,  test loss 1.472025, test error 50.80
# Epoch   200, train loss 0.496491, train error 15.32,  test loss 2.175428, test error 53.80
# Epoch   300, train loss 0.336721, train error 10.55,  test loss 3.143187, test error 54.10
# Epoch   400, train loss 0.249579, train error 8.57,  test loss 4.237134, test error 56.00
# Epoch   500, train loss 0.237484, train error 8.07,  test loss 5.496438, test error 56.10
# Epoch   600, train loss 0.153264, train error 5.53,  test loss 6.644299, test error 57.00
# Epoch   700, train loss 0.207302, train error 7.25,  test loss 7.817928, test error 57.22
# Epoch   800, train loss 0.009944, train error 0.00,  test loss 8.625387, test error 56.50
# Epoch   900, train loss 0.005619, train error 0.00,  test loss 9.242990, test error 56.50
# Training model with  50 hidden variables
# Epoch     0, train loss 2.094433, train error 76.95,  test loss 2.058111, test error 77.03
# Epoch   100, train loss 0.721545, train error 22.55,  test loss 1.555068, test error 50.25
# Epoch   200, train loss 0.421013, train error 13.80,  test loss 2.485005, test error 52.33
# Epoch   300, train loss 0.205044, train error 6.18,  test loss 3.763631, test error 54.75
# Epoch   400, train loss 0.127881, train error 4.12,  test loss 5.310723, test error 54.85
# Epoch   500, train loss 0.013602, train error 0.00,  test loss 6.342132, test error 54.58
# Epoch   600, train loss 0.008250, train error 0.00,  test loss 6.957506, test error 54.62
# Epoch   700, train loss 0.006005, train error 0.00,  test loss 7.405295, test error 54.60
# Epoch   800, train loss 0.004646, train error 0.00,  test loss 7.791891, test error 54.97
# Epoch   900, train loss 0.003678, train error 0.00,  test loss 8.085681, test error 54.83
# Training model with  55 hidden variables
# Epoch     0, train loss 2.082130, train error 76.57,  test loss 2.041359, test error 76.03
# Epoch   100, train loss 0.652525, train error 19.75,  test loss 1.703493, test error 52.35
# Epoch   200, train loss 0.222757, train error 5.35,  test loss 2.996425, test error 54.88
# Epoch   300, train loss 0.042156, train error 0.05,  test loss 4.687511, test error 55.83
# Epoch   400, train loss 0.015050, train error 0.00,  test loss 5.672657, test error 55.47
# Epoch   500, train loss 0.008612, train error 0.00,  test loss 6.284789, test error 55.83
# Epoch   600, train loss 0.005868, train error 0.00,  test loss 6.718080, test error 55.90
# Epoch   700, train loss 0.004368, train error 0.00,  test loss 7.057802, test error 55.95
# Epoch   800, train loss 0.003447, train error 0.00,  test loss 7.325341, test error 55.65
# Epoch   900, train loss 0.002827, train error 0.00,  test loss 7.558485, test error 55.65
# Training model with  60 hidden variables
# Epoch     0, train loss 2.040046, train error 75.22,  test loss 1.974283, test error 75.10
# Epoch   100, train loss 0.516085, train error 14.20,  test loss 1.759832, test error 52.28
# Epoch   200, train loss 0.112378, train error 1.43,  test loss 3.376225, test error 53.97
# Epoch   300, train loss 0.019916, train error 0.00,  test loss 4.693745, test error 54.75
# Epoch   400, train loss 0.009624, train error 0.00,  test loss 5.382390, test error 54.67
# Epoch   500, train loss 0.005940, train error 0.00,  test loss 5.827002, test error 54.85
# Epoch   600, train loss 0.004266, train error 0.00,  test loss 6.156022, test error 55.00
# Epoch   700, train loss 0.003271, train error 0.00,  test loss 6.414523, test error 55.00
# Epoch   800, train loss 0.002632, train error 0.00,  test loss 6.630440, test error 55.00
# Epoch   900, train loss 0.002187, train error 0.00,  test loss 6.818153, test error 55.05
# Training model with  70 hidden variables
# Epoch     0, train loss 2.055165, train error 76.07,  test loss 2.013245, test error 75.35
# Epoch   100, train loss 0.365016, train error 9.10,  test loss 1.939442, test error 50.88
# Epoch   200, train loss 0.034647, train error 0.00,  test loss 3.692281, test error 53.70
# Epoch   300, train loss 0.011291, train error 0.00,  test loss 4.545517, test error 54.15
# Epoch   400, train loss 0.006265, train error 0.00,  test loss 5.014308, test error 54.45
# Epoch   500, train loss 0.004181, train error 0.00,  test loss 5.346849, test error 54.58
# Epoch   600, train loss 0.003099, train error 0.00,  test loss 5.591961, test error 54.58
# Epoch   700, train loss 0.002425, train error 0.00,  test loss 5.795585, test error 54.65
# Epoch   800, train loss 0.001985, train error 0.00,  test loss 5.967484, test error 54.58
# Epoch   900, train loss 0.001664, train error 0.00,  test loss 6.112679, test error 54.60
# Training model with  80 hidden variables
# Epoch     0, train loss 2.038565, train error 76.45,  test loss 1.977551, test error 75.75
# Epoch   100, train loss 0.260834, train error 5.62,  test loss 2.096685, test error 51.88
# Epoch   200, train loss 0.019691, train error 0.00,  test loss 3.437575, test error 52.35
# Epoch   300, train loss 0.007926, train error 0.00,  test loss 3.999918, test error 51.88
# Epoch   400, train loss 0.004693, train error 0.00,  test loss 4.340951, test error 52.05
# Epoch   500, train loss 0.003217, train error 0.00,  test loss 4.578549, test error 51.97
# Epoch   600, train loss 0.002417, train error 0.00,  test loss 4.763559, test error 52.05
# Epoch   700, train loss 0.001918, train error 0.00,  test loss 4.911485, test error 52.08
# Epoch   800, train loss 0.001580, train error 0.00,  test loss 5.036744, test error 52.12
# Epoch   900, train loss 0.001338, train error 0.00,  test loss 5.146526, test error 52.05
# Training model with  90 hidden variables
# Epoch     0, train loss 2.029592, train error 76.10,  test loss 1.978681, test error 74.60
# Epoch   100, train loss 0.171936, train error 1.97,  test loss 2.139211, test error 51.25
# Epoch   200, train loss 0.016792, train error 0.00,  test loss 3.187415, test error 51.65
# Epoch   300, train loss 0.007107, train error 0.00,  test loss 3.621904, test error 51.30
# Epoch   400, train loss 0.004283, train error 0.00,  test loss 3.886900, test error 51.12
# Epoch   500, train loss 0.002991, train error 0.00,  test loss 4.077240, test error 51.25
# Epoch   600, train loss 0.002267, train error 0.00,  test loss 4.226903, test error 51.25
# Epoch   700, train loss 0.001808, train error 0.00,  test loss 4.348115, test error 51.28
# Epoch   800, train loss 0.001494, train error 0.00,  test loss 4.450077, test error 51.33
# Epoch   900, train loss 0.001267, train error 0.00,  test loss 4.539524, test error 51.28
# Training model with 100 hidden variables
# Epoch     0, train loss 1.985567, train error 73.35,  test loss 1.927831, test error 74.95
# Epoch   100, train loss 0.096089, train error 0.18,  test loss 2.382430, test error 52.67
# Epoch   200, train loss 0.012231, train error 0.00,  test loss 3.286557, test error 52.50
# Epoch   300, train loss 0.005647, train error 0.00,  test loss 3.665325, test error 52.72
# Epoch   400, train loss 0.003535, train error 0.00,  test loss 3.909216, test error 52.90
# Epoch   500, train loss 0.002509, train error 0.00,  test loss 4.085718, test error 52.67
# Epoch   600, train loss 0.001926, train error 0.00,  test loss 4.223528, test error 52.62
# Epoch   700, train loss 0.001547, train error 0.00,  test loss 4.339797, test error 52.75
# Epoch   800, train loss 0.001285, train error 0.00,  test loss 4.436807, test error 52.80
# Epoch   900, train loss 0.001094, train error 0.00,  test loss 4.521754, test error 52.78
# Training model with 120 hidden variables
# Epoch     0, train loss 1.989681, train error 74.85,  test loss 1.937484, test error 75.55
# Epoch   100, train loss 0.050479, train error 0.00,  test loss 2.305449, test error 51.50
# Epoch   200, train loss 0.009437, train error 0.00,  test loss 2.930984, test error 51.20
# Epoch   300, train loss 0.004671, train error 0.00,  test loss 3.210203, test error 50.90
# Epoch   400, train loss 0.002992, train error 0.00,  test loss 3.394897, test error 51.03
# Epoch   500, train loss 0.002158, train error 0.00,  test loss 3.530399, test error 51.00
# Epoch   600, train loss 0.001668, train error 0.00,  test loss 3.638915, test error 50.97
# Epoch   700, train loss 0.001349, train error 0.00,  test loss 3.727820, test error 50.97
# Epoch   800, train loss 0.001127, train error 0.00,  test loss 3.803711, test error 50.90
# Epoch   900, train loss 0.000963, train error 0.00,  test loss 3.869827, test error 50.95
# Training model with 140 hidden variables
# Epoch     0, train loss 1.960739, train error 72.03,  test loss 1.876567, test error 72.88
# Epoch   100, train loss 0.035405, train error 0.00,  test loss 2.185389, test error 49.70
# Epoch   200, train loss 0.008077, train error 0.00,  test loss 2.695116, test error 49.85
# Epoch   300, train loss 0.004116, train error 0.00,  test loss 2.928431, test error 49.72
# Epoch   400, train loss 0.002673, train error 0.00,  test loss 3.082628, test error 49.45
# Epoch   500, train loss 0.001946, train error 0.00,  test loss 3.196991, test error 49.40
# Epoch   600, train loss 0.001514, train error 0.00,  test loss 3.289494, test error 49.35
# Epoch   700, train loss 0.001230, train error 0.00,  test loss 3.365597, test error 49.28
# Epoch   800, train loss 0.001031, train error 0.00,  test loss 3.430875, test error 49.30
# Epoch   900, train loss 0.000883, train error 0.00,  test loss 3.487965, test error 49.08
# Training model with 160 hidden variables
# Epoch     0, train loss 1.929316, train error 70.28,  test loss 1.847042, test error 70.35
# Epoch   100, train loss 0.029792, train error 0.00,  test loss 2.028721, test error 47.72
# Epoch   200, train loss 0.007346, train error 0.00,  test loss 2.427762, test error 47.45
# Epoch   300, train loss 0.003838, train error 0.00,  test loss 2.619765, test error 47.47
# Epoch   400, train loss 0.002521, train error 0.00,  test loss 2.749197, test error 47.60
# Epoch   500, train loss 0.001842, train error 0.00,  test loss 2.846543, test error 47.70
# Epoch   600, train loss 0.001437, train error 0.00,  test loss 2.923087, test error 47.60
# Epoch   700, train loss 0.001170, train error 0.00,  test loss 2.986810, test error 47.58
# Epoch   800, train loss 0.000981, train error 0.00,  test loss 3.041751, test error 47.50
# Epoch   900, train loss 0.000842, train error 0.00,  test loss 3.089407, test error 47.58
# Training model with 180 hidden variables
# Epoch     0, train loss 1.915295, train error 71.43,  test loss 1.849715, test error 72.95
# Epoch   100, train loss 0.024013, train error 0.00,  test loss 2.058107, test error 48.78
# Epoch   200, train loss 0.006519, train error 0.00,  test loss 2.413310, test error 48.75
# Epoch   300, train loss 0.003506, train error 0.00,  test loss 2.594831, test error 48.83
# Epoch   400, train loss 0.002324, train error 0.00,  test loss 2.713441, test error 48.72
# Epoch   500, train loss 0.001713, train error 0.00,  test loss 2.803835, test error 48.92
# Epoch   600, train loss 0.001342, train error 0.00,  test loss 2.875498, test error 48.90
# Epoch   700, train loss 0.001096, train error 0.00,  test loss 2.935362, test error 48.90
# Epoch   800, train loss 0.000922, train error 0.00,  test loss 2.986633, test error 48.95
# Epoch   900, train loss 0.000792, train error 0.00,  test loss 3.031923, test error 48.92
# Training model with 200 hidden variables
# Epoch     0, train loss 1.922059, train error 70.30,  test loss 1.879089, test error 72.65
# Epoch   100, train loss 0.020127, train error 0.00,  test loss 1.980905, test error 48.38
# Epoch   200, train loss 0.005952, train error 0.00,  test loss 2.285107, test error 48.25
# Epoch   300, train loss 0.003258, train error 0.00,  test loss 2.440972, test error 48.40
# Epoch   400, train loss 0.002180, train error 0.00,  test loss 2.546869, test error 48.33
# Epoch   500, train loss 0.001613, train error 0.00,  test loss 2.627382, test error 48.33
# Epoch   600, train loss 0.001267, train error 0.00,  test loss 2.692059, test error 48.40
# Epoch   700, train loss 0.001038, train error 0.00,  test loss 2.746250, test error 48.33
# Epoch   800, train loss 0.000874, train error 0.00,  test loss 2.792612, test error 48.38
# Epoch   900, train loss 0.000752, train error 0.00,  test loss 2.833037, test error 48.25
# Training model with 250 hidden variables
# Epoch     0, train loss 1.918668, train error 70.03,  test loss 1.853745, test error 72.50
# Epoch   100, train loss 0.016847, train error 0.00,  test loss 1.933722, test error 46.90
# Epoch   200, train loss 0.005341, train error 0.00,  test loss 2.191381, test error 46.70
# Epoch   300, train loss 0.002972, train error 0.00,  test loss 2.327343, test error 46.90
# Epoch   400, train loss 0.002008, train error 0.00,  test loss 2.421392, test error 46.92
# Epoch   500, train loss 0.001495, train error 0.00,  test loss 2.492326, test error 47.00
# Epoch   600, train loss 0.001180, train error 0.00,  test loss 2.550171, test error 47.08
# Epoch   700, train loss 0.000970, train error 0.00,  test loss 2.598528, test error 47.03
# Epoch   800, train loss 0.000819, train error 0.00,  test loss 2.640223, test error 47.03
# Epoch   900, train loss 0.000707, train error 0.00,  test loss 2.676312, test error 47.15
# Training model with 300 hidden variables
# Epoch     0, train loss 1.858352, train error 67.28,  test loss 1.791405, test error 69.82
# Epoch   100, train loss 0.014742, train error 0.00,  test loss 1.807293, test error 46.50
# Epoch   200, train loss 0.004897, train error 0.00,  test loss 2.022639, test error 46.53
# Epoch   300, train loss 0.002769, train error 0.00,  test loss 2.137437, test error 46.22
# Epoch   400, train loss 0.001884, train error 0.00,  test loss 2.217610, test error 46.12
# Epoch   500, train loss 0.001408, train error 0.00,  test loss 2.277838, test error 45.97
# Epoch   600, train loss 0.001115, train error 0.00,  test loss 2.326722, test error 45.97
# Epoch   700, train loss 0.000918, train error 0.00,  test loss 2.368500, test error 45.90
# Epoch   800, train loss 0.000777, train error 0.00,  test loss 2.403236, test error 45.88
# Epoch   900, train loss 0.000671, train error 0.00,  test loss 2.434742, test error 45.88
# Training model with 400 hidden variables
# Epoch     0, train loss 1.862645, train error 66.85,  test loss 1.788283, test error 68.82
# Epoch   100, train loss 0.011636, train error 0.00,  test loss 1.754411, test error 45.60
# Epoch   200, train loss 0.004147, train error 0.00,  test loss 1.925375, test error 45.67
# Epoch   300, train loss 0.002396, train error 0.00,  test loss 2.022770, test error 45.58
# Epoch   400, train loss 0.001651, train error 0.00,  test loss 2.091708, test error 45.75
# Epoch   500, train loss 0.001244, train error 0.00,  test loss 2.144141, test error 45.75
# Epoch   600, train loss 0.000991, train error 0.00,  test loss 2.187105, test error 45.72
# Epoch   700, train loss 0.000819, train error 0.00,  test loss 2.223197, test error 45.65
# Epoch   800, train loss 0.000695, train error 0.00,  test loss 2.254652, test error 45.65
# Epoch   900, train loss 0.000602, train error 0.00,  test loss 2.281949, test error 45.62

# %%
import matplotlib.pyplot as plt
import numpy as np

# Assuming data['y'] is available and contains the training examples
num_training_examples = len(data['y'])

# Find the index where total_weights_all is closest to num_training_examples
closest_index = np.argmin(np.abs(np.array(total_weights_all) - num_training_examples))

# Get the corresponding value of hidden variables
hidden_variable_at_num_training_examples = hidden_variables[closest_index]

# Plot the results
fig, ax = plt.subplots()
ax.plot(hidden_variables, errors_train_all, 'r-', label='train')
ax.plot(hidden_variables, errors_test_all, 'b-', label='test')

# Add a vertical line at the point where total weights equal the number of training examples
ax.axvline(x=hidden_variable_at_num_training_examples, color='g', linestyle='--', label='N(weights) = N(train)')

ax.set_ylim(0, 100)
ax.set_xlabel('No. hidden variables')
ax.set_ylabel('Error')
ax.legend()
plt.show()
